# %%
import pandas_datareader.data as web
from datetime import datetime
import numpy as np
import pandas as pd
from multiprocessing import Pool
import tqdm
import gc

# Local 
import GetStockData
from StockAnalysis import Analysis

# %% [markdown]
# #### Load List of Stock Symbol

# %%
GetStockData.update_tickers_list()
nasdaq = GetStockData.get_nasdaq_tickers()
nasdaq.shape
# Out:
# (5884, 2)

# %%
# Get today's date
t = datetime.now().strftime('%m%d%Y')

# %%
# Create an empty list to store data 
bbands_outliers=[]

# %%
Analysis('GTLS').BBand_Outliers(last_n_days=3)
# Out:
# ['GTLS', 'On Upper Band']

# %%
# Define a function to find out all Bollinger Band Pattern, using with multiprocessing 

def All_BBands_Outliers(symbol, start = datetime(2020,3,1), end = datetime.now(), last_n_days = 3):
    return Analysis(symbol, start, end).BBand_Outliers(last_n_days = last_n_days)

# %%
# %%time

n_cpu = 4

with Pool(processes=n_cpu) as p:
    max_ = len(nasdaq.Symbol[900:1000])
    with tqdm.tqdm_notebook(total=max_) as pbar: # May need to change the tqdm_notebook later
        for i, r in enumerate(p.imap(All_BBands_Outliers, nasdaq.Symbol[900:1000])):
            bbands_outliers.append(r)
            pbar.update(1)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# CPU times: user 46.9 ms, sys: 141 ms, total: 188 ms
# Wall time: 10.1 s

# %%
len(bbands_outliers)
# Out:
# 100

# %%
bbands_outliers = [b for b in bbands_outliers if b != None]
results = pd.DataFrame(bbands_outliers, columns=['Symbol', 'BBIndicator'])

# %%
path = r'~/stock_analysis/Bollinger Band Analysis/'
filename = "Bollinger_Band_Indicator" + t + ".csv"
results.to_csv(path+filename)

# %%
results[(~results['BBIndicator'].isnull())]
# Out:
#    Symbol       BBIndicator
# 0    CARS
# 1    CARV
# 2    CASA     On Upper Band
# 3    CASH
# 4    CASI
# 5    CASS
# 6    CASY
# 7     CAT
# 8    CATB
# 9    CATC
# 10   CATM
# 11   CATO
# 12   CATS
# 13   CATY
# 14     CB
# 15   CBAN
# 16   CBAT     On Upper Band
# 17   CBAY
# 18    CBB     On Upper Band
# 19    CBD     On Lower Band
# 20   CBFV
# 21    CBH
# 22   CBIO     On Upper Band
# 23    CBL     On Upper Band
# 24   CBLI
# 25   CBMB
# 26   CBMG     On Lower Band
# 27   CBNK
# 28   CBOE
# 29   CBPO
# ..    ...               ...
# 70   CDEV  Above Upper Band
# 71    CDK
# 72   CDLX
# 73   CDMO     On Upper Band
# 74  CDMOP     On Upper Band
# 75   CDNA     On Upper Band
# 76   CDNS
# 77   CDOR
# 78    CDR
# 79   CDTX
# 80    CDW
# 81   CDXC  Above Upper Band
# 82   CDXS
# 83   CDZI
# 84     CE
# 85    CEA  Above Upper Band
# 86   CECE
# 87    CEE
# 88    CEI
# 89   CEIX
# 90    CEL
# 91   CELC
# 92   CELH
# 93   CELP
# 94    CEM     On Upper Band
# 95   CEMI
# 96    CEN
# 97   CENT
# 98  CENTA
# 99   CENX
#
# [100 rows x 2 columns]
